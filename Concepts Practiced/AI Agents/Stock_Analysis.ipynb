# %%
# !pip install crewai
# !pip install crewai-tools
# !pip install duckduckgo-search
# !pip install finnhub-python
# Out:
# Requirement already satisfied: crewai in c:\users\saket.khopkar\anaconda3\lib\site-packages (0.95.0)
# Requirement already satisfied: appdirs>=1.4.4 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from crewai) (1.4.4)
# Requirement already satisfied: auth0-python>=4.7.1 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from crewai) (4.10.0)
# Requirement already satisfied: blinker>=1.9.0 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from crewai) (1.9.0)
# Requirement already satisfied: chromadb>=0.5.23 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from crewai) (0.5.23)
# Requirement already satisfied: click>=8.1.7 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from crewai) (8.1.8)
# Requirement already satisfied: instructor>=1.3.3 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from crewai) (1.9.0)
# Requirement already satisfied: json-repair>=0.25.2 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from crewai) (0.47.3)
# Requirement already satisfied: jsonref>=1.1.0 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from crewai) (1.1.0)
# Requirement already satisfied: litellm>=1.44.22 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from crewai) (1.72.0)
# Requirement already satisfied: openai>=1.13.3 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from crewai) (1.91.0)
# Requirement already satisfied: openpyxl>=3.1.5 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from crewai) (3.1.5)
# Requirement already satisfied: opentelemetry-api>=1.22.0 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from crewai) (1.34.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-http>=1.22.0 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from crewai) (1.34.1)
# Requirement already satisfied: opentelemetry-sdk>=1.22.0 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from crewai) (1.34.1)
# Requirement already satisfied: pdfplumber>=0.11.4 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from crewai) (0.11.7)
# Requirement already satisfied: pydantic>=2.4.2 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from crewai) (2.11.7)
# Requirement already satisfied: python-dotenv>=1.0.0 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from crewai) (1.1.1)
# Requirement already satisfied: pyvis>=0.3.2 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from crewai) (0.3.2)
# Requirement already satisfied: regex>=2024.9.11 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from crewai) (2024.9.11)
# Requirement already satisfied: tomli-w>=1.1.0 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from crewai) (1.2.0)
# Requirement already satisfied: tomli>=2.0.2 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from crewai) (2.2.1)
# Requirement already satisfied: uv>=0.4.25 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from crewai) (0.7.14)
# Requirement already satisfied: aiohttp>=3.10.11 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from auth0-python>=4.7.1->crewai) (3.12.13)
# Requirement already satisfied: cryptography>=43.0.1 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from auth0-python>=4.7.1->crewai) (45.0.4)
# Requirement already satisfied: pyjwt>=2.8.0 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from auth0-python>=4.7.1->crewai) (2.8.0)
# Requirement already satisfied: requests>=2.32.3 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from auth0-python>=4.7.1->crewai) (2.32.3)
# Requirement already satisfied: urllib3>=2.2.3 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from auth0-python>=4.7.1->crewai) (2.5.0)
# Requirement already satisfied: build>=1.0.3 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from chromadb>=0.5.23->crewai) (1.2.2.post1)
# Requirement already satisfied: chroma-hnswlib==0.7.6 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from chromadb>=0.5.23->crewai) (0.7.6)
# Requirement already satisfied: fastapi>=0.95.2 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from chromadb>=0.5.23->crewai) (0.115.14)
# Requirement already satisfied: uvicorn>=0.18.3 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb>=0.5.23->crewai) (0.34.3)
# Requirement already satisfied: numpy>=1.22.5 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from chromadb>=0.5.23->crewai) (1.26.4)
# Requirement already satisfied: posthog>=2.4.0 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from chromadb>=0.5.23->crewai) (3.25.0)
# Requirement already satisfied: typing_extensions>=4.5.0 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from chromadb>=0.5.23->crewai) (4.14.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from chromadb>=0.5.23->crewai) (1.22.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from chromadb>=0.5.23->crewai) (1.34.1)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi>=0.41b0 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from chromadb>=0.5.23->crewai) (0.55b1)
# Requirement already satisfied: tokenizers<=0.20.3,>=0.13.2 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from chromadb>=0.5.23->crewai) (0.20.3)
# Requirement already satisfied: pypika>=0.48.9 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from chromadb>=0.5.23->crewai) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from chromadb>=0.5.23->crewai) (4.66.5)
# Requirement already satisfied: overrides>=7.3.1 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from chromadb>=0.5.23->crewai) (7.4.0)
# Requirement already satisfied: importlib-resources in c:\users\saket.khopkar\anaconda3\lib\site-packages (from chromadb>=0.5.23->crewai) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from chromadb>=0.5.23->crewai) (1.73.0)
# Requirement already satisfied: bcrypt>=4.0.1 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from chromadb>=0.5.23->crewai) (4.3.0)
# Requirement already satisfied: typer>=0.9.0 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from chromadb>=0.5.23->crewai) (0.15.4)
# Requirement already satisfied: kubernetes>=28.1.0 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from chromadb>=0.5.23->crewai) (33.1.0)
# Requirement already satisfied: tenacity>=8.2.3 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from chromadb>=0.5.23->crewai) (8.2.3)
# Requirement already satisfied: PyYAML>=6.0.0 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from chromadb>=0.5.23->crewai) (6.0.1)
# Requirement already satisfied: mmh3>=4.0.1 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from chromadb>=0.5.23->crewai) (5.1.0)
# Requirement already satisfied: orjson>=3.9.12 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from chromadb>=0.5.23->crewai) (3.10.18)
# Requirement already satisfied: httpx>=0.27.0 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from chromadb>=0.5.23->crewai) (0.28.1)
# Requirement already satisfied: rich>=10.11.0 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from chromadb>=0.5.23->crewai) (13.9.4)
# Requirement already satisfied: colorama in c:\users\saket.khopkar\anaconda3\lib\site-packages (from click>=8.1.7->crewai) (0.4.6)
# Requirement already satisfied: docstring-parser<1.0,>=0.16 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from instructor>=1.3.3->crewai) (0.16)
# Requirement already satisfied: jinja2<4.0.0,>=3.1.4 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from instructor>=1.3.3->crewai) (3.1.4)
# Requirement already satisfied: jiter<0.11,>=0.6.1 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from instructor>=1.3.3->crewai) (0.10.0)
# Requirement already satisfied: mkdocs-material>=9.5.49 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from instructor>=1.3.3->crewai) (9.6.14)
# Requirement already satisfied: mkdocs>=1.6.1 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from instructor>=1.3.3->crewai) (1.6.1)
# Requirement already satisfied: pre-commit>=4.2.0 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from instructor>=1.3.3->crewai) (4.2.0)
# Requirement already satisfied: pydantic-core<3.0.0,>=2.18.0 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from instructor>=1.3.3->crewai) (2.33.2)
# Requirement already satisfied: importlib-metadata>=6.8.0 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from litellm>=1.44.22->crewai) (7.0.1)
# Requirement already satisfied: jsonschema<5.0.0,>=4.22.0 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from litellm>=1.44.22->crewai) (4.23.0)
# Requirement already satisfied: tiktoken>=0.7.0 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from litellm>=1.44.22->crewai) (0.9.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from openai>=1.13.3->crewai) (4.2.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from openai>=1.13.3->crewai) (1.9.0)
# Requirement already satisfied: sniffio in c:\users\saket.khopkar\anaconda3\lib\site-packages (from openai>=1.13.3->crewai) (1.3.0)
# Requirement already satisfied: et-xmlfile in c:\users\saket.khopkar\anaconda3\lib\site-packages (from openpyxl>=3.1.5->crewai) (1.1.0)
# Requirement already satisfied: googleapis-common-protos~=1.52 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp-proto-http>=1.22.0->crewai) (1.70.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.34.1 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp-proto-http>=1.22.0->crewai) (1.34.1)
# Requirement already satisfied: opentelemetry-proto==1.34.1 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp-proto-http>=1.22.0->crewai) (1.34.1)
# Requirement already satisfied: protobuf<6.0,>=5.0 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from opentelemetry-proto==1.34.1->opentelemetry-exporter-otlp-proto-http>=1.22.0->crewai) (5.29.5)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.55b1 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from opentelemetry-sdk>=1.22.0->crewai) (0.55b1)
# Requirement already satisfied: pdfminer.six==20250506 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from pdfplumber>=0.11.4->crewai) (20250506)
# Requirement already satisfied: Pillow>=9.1 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from pdfplumber>=0.11.4->crewai) (11.2.1)
# Requirement already satisfied: pypdfium2>=4.18.0 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from pdfplumber>=0.11.4->crewai) (4.30.1)
# Requirement already satisfied: charset-normalizer>=2.0.0 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from pdfminer.six==20250506->pdfplumber>=0.11.4->crewai) (3.3.2)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from pydantic>=2.4.2->crewai) (0.6.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from pydantic>=2.4.2->crewai) (0.4.1)
# Requirement already satisfied: ipython>=5.3.0 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from pyvis>=0.3.2->crewai) (8.27.0)
# Requirement already satisfied: jsonpickle>=1.4.1 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from pyvis>=0.3.2->crewai) (4.1.1)
# Requirement already satisfied: networkx>=1.11 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from pyvis>=0.3.2->crewai) (3.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from aiohttp>=3.10.11->auth0-python>=4.7.1->crewai) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from aiohttp>=3.10.11->auth0-python>=4.7.1->crewai) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from aiohttp>=3.10.11->auth0-python>=4.7.1->crewai) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from aiohttp>=3.10.11->auth0-python>=4.7.1->crewai) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from aiohttp>=3.10.11->auth0-python>=4.7.1->crewai) (6.0.4)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from aiohttp>=3.10.11->auth0-python>=4.7.1->crewai) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from aiohttp>=3.10.11->auth0-python>=4.7.1->crewai) (1.20.1)
# Requirement already satisfied: idna>=2.8 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from anyio<5,>=3.5.0->openai>=1.13.3->crewai) (3.7)
# Requirement already satisfied: packaging>=19.1 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from build>=1.0.3->chromadb>=0.5.23->crewai) (24.1)
# Requirement already satisfied: pyproject_hooks in c:\users\saket.khopkar\anaconda3\lib\site-packages (from build>=1.0.3->chromadb>=0.5.23->crewai) (1.2.0)
# Requirement already satisfied: cffi>=1.14 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from cryptography>=43.0.1->auth0-python>=4.7.1->crewai) (1.17.1)
# Requirement already satisfied: starlette<0.47.0,>=0.40.0 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from fastapi>=0.95.2->chromadb>=0.5.23->crewai) (0.46.2)
# Requirement already satisfied: certifi in c:\users\saket.khopkar\anaconda3\lib\site-packages (from httpx>=0.27.0->chromadb>=0.5.23->crewai) (2025.7.9)
# Requirement already satisfied: httpcore==1.* in c:\users\saket.khopkar\anaconda3\lib\site-packages (from httpx>=0.27.0->chromadb>=0.5.23->crewai) (1.0.2)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb>=0.5.23->crewai) (0.14.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from importlib-metadata>=6.8.0->litellm>=1.44.22->crewai) (3.17.0)
# Requirement already satisfied: decorator in c:\users\saket.khopkar\anaconda3\lib\site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (0.19.1)
# Requirement already satisfied: matplotlib-inline in c:\users\saket.khopkar\anaconda3\lib\site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (2.19.2)
# Requirement already satisfied: stack-data in c:\users\saket.khopkar\anaconda3\lib\site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (0.2.0)
# Requirement already satisfied: traitlets>=5.13.0 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (5.14.3)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from jinja2<4.0.0,>=3.1.4->instructor>=1.3.3->crewai) (2.1.3)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from jsonschema<5.0.0,>=4.22.0->litellm>=1.44.22->crewai) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from jsonschema<5.0.0,>=4.22.0->litellm>=1.44.22->crewai) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from jsonschema<5.0.0,>=4.22.0->litellm>=1.44.22->crewai) (0.10.6)
# Requirement already satisfied: six>=1.9.0 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb>=0.5.23->crewai) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb>=0.5.23->crewai) (2.9.0.post0)
# Requirement already satisfied: google-auth>=1.0.1 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb>=0.5.23->crewai) (2.40.3)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb>=0.5.23->crewai) (1.8.0)
# Requirement already satisfied: requests-oauthlib in c:\users\saket.khopkar\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb>=0.5.23->crewai) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb>=0.5.23->crewai) (3.3.1)
# Requirement already satisfied: durationpy>=0.7 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb>=0.5.23->crewai) (0.10)
# Requirement already satisfied: ghp-import>=1.0 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from mkdocs>=1.6.1->instructor>=1.3.3->crewai) (2.1.0)
# Requirement already satisfied: markdown>=3.3.6 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from mkdocs>=1.6.1->instructor>=1.3.3->crewai) (3.8.2)
# Requirement already satisfied: mergedeep>=1.3.4 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from mkdocs>=1.6.1->instructor>=1.3.3->crewai) (1.3.4)
# Requirement already satisfied: mkdocs-get-deps>=0.2.0 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from mkdocs>=1.6.1->instructor>=1.3.3->crewai) (0.2.0)
# Requirement already satisfied: pathspec>=0.11.1 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from mkdocs>=1.6.1->instructor>=1.3.3->crewai) (0.12.1)
# Requirement already satisfied: pyyaml-env-tag>=0.1 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from mkdocs>=1.6.1->instructor>=1.3.3->crewai) (1.1)
# Requirement already satisfied: watchdog>=2.0 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from mkdocs>=1.6.1->instructor>=1.3.3->crewai) (4.0.1)
# Requirement already satisfied: babel~=2.10 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from mkdocs-material>=9.5.49->instructor>=1.3.3->crewai) (2.11.0)
# Requirement already satisfied: backrefs~=5.7.post1 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from mkdocs-material>=9.5.49->instructor>=1.3.3->crewai) (5.9)
# Requirement already satisfied: mkdocs-material-extensions~=1.3 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from mkdocs-material>=9.5.49->instructor>=1.3.3->crewai) (1.3.1)
# Requirement already satisfied: paginate~=0.5 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from mkdocs-material>=9.5.49->instructor>=1.3.3->crewai) (0.5.7)
# Requirement already satisfied: pymdown-extensions~=10.2 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from mkdocs-material>=9.5.49->instructor>=1.3.3->crewai) (10.16)
# Requirement already satisfied: coloredlogs in c:\users\saket.khopkar\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb>=0.5.23->crewai) (15.0.1)
# Requirement already satisfied: flatbuffers in c:\users\saket.khopkar\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb>=0.5.23->crewai) (25.2.10)
# Requirement already satisfied: sympy in c:\users\saket.khopkar\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb>=0.5.23->crewai) (1.13.2)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.55b1 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=0.5.23->crewai) (0.55b1)
# Requirement already satisfied: opentelemetry-instrumentation==0.55b1 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=0.5.23->crewai) (0.55b1)
# Requirement already satisfied: opentelemetry-util-http==0.55b1 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=0.5.23->crewai) (0.55b1)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from opentelemetry-instrumentation==0.55b1->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=0.5.23->crewai) (1.14.1)
# Requirement already satisfied: asgiref~=3.0 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from opentelemetry-instrumentation-asgi==0.55b1->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=0.5.23->crewai) (3.8.1)
# Requirement already satisfied: monotonic>=1.5 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from posthog>=2.4.0->chromadb>=0.5.23->crewai) (1.6)
# Requirement already satisfied: backoff>=1.10.0 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from posthog>=2.4.0->chromadb>=0.5.23->crewai) (2.2.1)
# Requirement already satisfied: cfgv>=2.0.0 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from pre-commit>=4.2.0->instructor>=1.3.3->crewai) (3.4.0)
# Requirement already satisfied: identify>=1.0.0 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from pre-commit>=4.2.0->instructor>=1.3.3->crewai) (2.6.12)
# Requirement already satisfied: nodeenv>=0.11.1 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from pre-commit>=4.2.0->instructor>=1.3.3->crewai) (1.9.1)
# Requirement already satisfied: virtualenv>=20.10.0 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from pre-commit>=4.2.0->instructor>=1.3.3->crewai) (20.31.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from rich>=10.11.0->chromadb>=0.5.23->crewai) (2.2.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from tokenizers<=0.20.3,>=0.13.2->chromadb>=0.5.23->crewai) (0.33.0)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from typer>=0.9.0->chromadb>=0.5.23->crewai) (1.5.4)
# Requirement already satisfied: httptools>=0.6.3 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb>=0.5.23->crewai) (0.6.4)
# Requirement already satisfied: watchfiles>=0.13 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb>=0.5.23->crewai) (1.1.0)
# Requirement already satisfied: websockets>=10.4 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb>=0.5.23->crewai) (15.0.1)
# Requirement already satisfied: pytz>=2015.7 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from babel~=2.10->mkdocs-material>=9.5.49->instructor>=1.3.3->crewai) (2024.1)
# Requirement already satisfied: pycparser in c:\users\saket.khopkar\anaconda3\lib\site-packages (from cffi>=1.14->cryptography>=43.0.1->auth0-python>=4.7.1->crewai) (2.21)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb>=0.5.23->crewai) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb>=0.5.23->crewai) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb>=0.5.23->crewai) (4.9.1)
# Requirement already satisfied: filelock in c:\users\saket.khopkar\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers<=0.20.3,>=0.13.2->chromadb>=0.5.23->crewai) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers<=0.20.3,>=0.13.2->chromadb>=0.5.23->crewai) (2024.6.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=5.3.0->pyvis>=0.3.2->crewai) (0.8.3)
# Requirement already satisfied: mdurl~=0.1 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb>=0.5.23->crewai) (0.1.0)
# Requirement already satisfied: platformdirs>=2.2.0 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from mkdocs-get-deps>=0.2.0->mkdocs>=1.6.1->instructor>=1.3.3->crewai) (3.10.0)
# Requirement already satisfied: wcwidth in c:\users\saket.khopkar\anaconda3\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=5.3.0->pyvis>=0.3.2->crewai) (0.2.5)
# Requirement already satisfied: distlib<1,>=0.3.7 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from virtualenv>=20.10.0->pre-commit>=4.2.0->instructor>=1.3.3->crewai) (0.3.9)
# Requirement already satisfied: humanfriendly>=9.1 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb>=0.5.23->crewai) (10.0)
# Requirement already satisfied: executing in c:\users\saket.khopkar\anaconda3\lib\site-packages (from stack-data->ipython>=5.3.0->pyvis>=0.3.2->crewai) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\saket.khopkar\anaconda3\lib\site-packages (from stack-data->ipython>=5.3.0->pyvis>=0.3.2->crewai) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\saket.khopkar\anaconda3\lib\site-packages (from stack-data->ipython>=5.3.0->pyvis>=0.3.2->crewai) (0.2.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb>=0.5.23->crewai) (1.3.0)
# Requirement already satisfied: pyreadline3 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.14.1->chromadb>=0.5.23->crewai) (3.5.4)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb>=0.5.23->crewai) (0.4.8)
# Requirement already satisfied: crewai-tools in c:\users\saket.khopkar\anaconda3\lib\site-packages (0.25.8)
# Requirement already satisfied: beautifulsoup4>=4.12.3 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from crewai-tools) (4.12.3)
# Requirement already satisfied: chromadb>=0.4.22 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from crewai-tools) (0.5.23)
# Requirement already satisfied: crewai>=0.86.0 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from crewai-tools) (0.95.0)
# Requirement already satisfied: docker>=7.1.0 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from crewai-tools) (7.1.0)
# Requirement already satisfied: docx2txt>=0.8 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from crewai-tools) (0.9)
# Requirement already satisfied: embedchain>=0.1.114 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from crewai-tools) (0.1.128)
# Requirement already satisfied: lancedb>=0.5.4 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from crewai-tools) (0.24.0)
# Requirement already satisfied: linkup-sdk>=0.2.1 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from crewai-tools) (0.2.8)
# Requirement already satisfied: openai>=1.12.0 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from crewai-tools) (1.91.0)
# Requirement already satisfied: pydantic>=2.6.1 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from crewai-tools) (2.11.7)
# Requirement already satisfied: pyright>=1.1.350 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from crewai-tools) (1.1.402)
# Requirement already satisfied: pytest>=8.0.0 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from crewai-tools) (8.4.1)
# Requirement already satisfied: pytube>=15.0.0 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from crewai-tools) (15.0.0)
# Requirement already satisfied: requests>=2.31.0 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from crewai-tools) (2.32.3)
# Requirement already satisfied: scrapegraph-py>=1.8.0 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from crewai-tools) (1.14.1)
# Requirement already satisfied: selenium>=4.18.1 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from crewai-tools) (4.34.2)
# Requirement already satisfied: serpapi>=0.1.5 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from crewai-tools) (0.1.5)
# Requirement already satisfied: spider-client>=0.1.25 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from crewai-tools) (0.1.52)
# Requirement already satisfied: weaviate-client>=4.9.6 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from crewai-tools) (4.15.4)
# Requirement already satisfied: soupsieve>1.2 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from beautifulsoup4>=4.12.3->crewai-tools) (2.5)
# Requirement already satisfied: build>=1.0.3 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from chromadb>=0.4.22->crewai-tools) (1.2.2.post1)
# Requirement already satisfied: chroma-hnswlib==0.7.6 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from chromadb>=0.4.22->crewai-tools) (0.7.6)
# Requirement already satisfied: fastapi>=0.95.2 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from chromadb>=0.4.22->crewai-tools) (0.115.14)
# Requirement already satisfied: uvicorn>=0.18.3 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb>=0.4.22->crewai-tools) (0.34.3)
# Requirement already satisfied: numpy>=1.22.5 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from chromadb>=0.4.22->crewai-tools) (1.26.4)
# Requirement already satisfied: posthog>=2.4.0 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from chromadb>=0.4.22->crewai-tools) (3.25.0)
# Requirement already satisfied: typing_extensions>=4.5.0 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from chromadb>=0.4.22->crewai-tools) (4.14.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from chromadb>=0.4.22->crewai-tools) (1.22.0)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from chromadb>=0.4.22->crewai-tools) (1.34.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from chromadb>=0.4.22->crewai-tools) (1.34.1)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi>=0.41b0 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from chromadb>=0.4.22->crewai-tools) (0.55b1)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from chromadb>=0.4.22->crewai-tools) (1.34.1)
# Requirement already satisfied: tokenizers<=0.20.3,>=0.13.2 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from chromadb>=0.4.22->crewai-tools) (0.20.3)
# Requirement already satisfied: pypika>=0.48.9 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from chromadb>=0.4.22->crewai-tools) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from chromadb>=0.4.22->crewai-tools) (4.66.5)
# Requirement already satisfied: overrides>=7.3.1 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from chromadb>=0.4.22->crewai-tools) (7.4.0)
# Requirement already satisfied: importlib-resources in c:\users\saket.khopkar\anaconda3\lib\site-packages (from chromadb>=0.4.22->crewai-tools) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from chromadb>=0.4.22->crewai-tools) (1.73.0)
# Requirement already satisfied: bcrypt>=4.0.1 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from chromadb>=0.4.22->crewai-tools) (4.3.0)
# Requirement already satisfied: typer>=0.9.0 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from chromadb>=0.4.22->crewai-tools) (0.15.4)
# Requirement already satisfied: kubernetes>=28.1.0 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from chromadb>=0.4.22->crewai-tools) (33.1.0)
# Requirement already satisfied: tenacity>=8.2.3 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from chromadb>=0.4.22->crewai-tools) (8.2.3)
# Requirement already satisfied: PyYAML>=6.0.0 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from chromadb>=0.4.22->crewai-tools) (6.0.1)
# Requirement already satisfied: mmh3>=4.0.1 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from chromadb>=0.4.22->crewai-tools) (5.1.0)
# Requirement already satisfied: orjson>=3.9.12 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from chromadb>=0.4.22->crewai-tools) (3.10.18)
# Requirement already satisfied: httpx>=0.27.0 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from chromadb>=0.4.22->crewai-tools) (0.28.1)
# Requirement already satisfied: rich>=10.11.0 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from chromadb>=0.4.22->crewai-tools) (13.9.4)
# Requirement already satisfied: appdirs>=1.4.4 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from crewai>=0.86.0->crewai-tools) (1.4.4)
# Requirement already satisfied: auth0-python>=4.7.1 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from crewai>=0.86.0->crewai-tools) (4.10.0)
# Requirement already satisfied: blinker>=1.9.0 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from crewai>=0.86.0->crewai-tools) (1.9.0)
# Requirement already satisfied: click>=8.1.7 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from crewai>=0.86.0->crewai-tools) (8.1.8)
# Requirement already satisfied: instructor>=1.3.3 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from crewai>=0.86.0->crewai-tools) (1.9.0)
# Requirement already satisfied: json-repair>=0.25.2 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from crewai>=0.86.0->crewai-tools) (0.47.3)
# Requirement already satisfied: jsonref>=1.1.0 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from crewai>=0.86.0->crewai-tools) (1.1.0)
# Requirement already satisfied: litellm>=1.44.22 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from crewai>=0.86.0->crewai-tools) (1.72.0)
# Requirement already satisfied: openpyxl>=3.1.5 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from crewai>=0.86.0->crewai-tools) (3.1.5)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-http>=1.22.0 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from crewai>=0.86.0->crewai-tools) (1.34.1)
# Requirement already satisfied: pdfplumber>=0.11.4 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from crewai>=0.86.0->crewai-tools) (0.11.7)
# Requirement already satisfied: python-dotenv>=1.0.0 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from crewai>=0.86.0->crewai-tools) (1.1.1)
# Requirement already satisfied: pyvis>=0.3.2 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from crewai>=0.86.0->crewai-tools) (0.3.2)
# Requirement already satisfied: regex>=2024.9.11 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from crewai>=0.86.0->crewai-tools) (2024.9.11)
# Requirement already satisfied: tomli-w>=1.1.0 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from crewai>=0.86.0->crewai-tools) (1.2.0)
# Requirement already satisfied: tomli>=2.0.2 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from crewai>=0.86.0->crewai-tools) (2.2.1)
# Requirement already satisfied: uv>=0.4.25 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from crewai>=0.86.0->crewai-tools) (0.7.14)
# Requirement already satisfied: pywin32>=304 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from docker>=7.1.0->crewai-tools) (305.1)
# Requirement already satisfied: urllib3>=1.26.0 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from docker>=7.1.0->crewai-tools) (2.5.0)
# Requirement already satisfied: alembic<2.0.0,>=1.13.1 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from embedchain>=0.1.114->crewai-tools) (1.16.2)
# Requirement already satisfied: gptcache<0.2.0,>=0.1.43 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from embedchain>=0.1.114->crewai-tools) (0.1.44)
# Requirement already satisfied: langchain<0.4.0,>=0.3.1 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from embedchain>=0.1.114->crewai-tools) (0.3.26)
# Requirement already satisfied: langchain-cohere<0.4.0,>=0.3.0 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from embedchain>=0.1.114->crewai-tools) (0.3.5)
# Requirement already satisfied: langchain-community<0.4.0,>=0.3.1 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from embedchain>=0.1.114->crewai-tools) (0.3.26)
# Requirement already satisfied: langchain-openai<0.3.0,>=0.2.1 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from embedchain>=0.1.114->crewai-tools) (0.2.14)
# Requirement already satisfied: langsmith<0.4.0,>=0.3.18 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from embedchain>=0.1.114->crewai-tools) (0.3.45)
# Requirement already satisfied: mem0ai<0.2.0,>=0.1.54 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from embedchain>=0.1.114->crewai-tools) (0.1.113)
# Requirement already satisfied: pypdf<6.0.0,>=5.0.0 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from embedchain>=0.1.114->crewai-tools) (5.7.0)
# Requirement already satisfied: pysbd<0.4.0,>=0.3.4 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from embedchain>=0.1.114->crewai-tools) (0.3.4)
# Requirement already satisfied: schema<0.8.0,>=0.7.5 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from embedchain>=0.1.114->crewai-tools) (0.7.7)
# Requirement already satisfied: sqlalchemy<3.0.0,>=2.0.27 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from embedchain>=0.1.114->crewai-tools) (2.0.34)
# Requirement already satisfied: deprecation in c:\users\saket.khopkar\anaconda3\lib\site-packages (from lancedb>=0.5.4->crewai-tools) (2.1.0)
# Requirement already satisfied: packaging in c:\users\saket.khopkar\anaconda3\lib\site-packages (from lancedb>=0.5.4->crewai-tools) (24.1)
# Requirement already satisfied: pyarrow>=16 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from lancedb>=0.5.4->crewai-tools) (16.1.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from openai>=1.12.0->crewai-tools) (4.2.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from openai>=1.12.0->crewai-tools) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from openai>=1.12.0->crewai-tools) (0.10.0)
# Requirement already satisfied: sniffio in c:\users\saket.khopkar\anaconda3\lib\site-packages (from openai>=1.12.0->crewai-tools) (1.3.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from pydantic>=2.6.1->crewai-tools) (0.6.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from pydantic>=2.6.1->crewai-tools) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from pydantic>=2.6.1->crewai-tools) (0.4.1)
# Requirement already satisfied: nodeenv>=1.6.0 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from pyright>=1.1.350->crewai-tools) (1.9.1)
# Requirement already satisfied: colorama>=0.4 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from pytest>=8.0.0->crewai-tools) (0.4.6)
# Requirement already satisfied: iniconfig>=1 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from pytest>=8.0.0->crewai-tools) (1.1.1)
# Requirement already satisfied: pluggy<2,>=1.5 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from pytest>=8.0.0->crewai-tools) (1.6.0)
# Requirement already satisfied: pygments>=2.7.2 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from pytest>=8.0.0->crewai-tools) (2.19.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from requests>=2.31.0->crewai-tools) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from requests>=2.31.0->crewai-tools) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from requests>=2.31.0->crewai-tools) (2025.7.9)
# Requirement already satisfied: aiohttp>=3.10 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from scrapegraph-py>=1.8.0->crewai-tools) (3.12.13)
# Requirement already satisfied: trio~=0.30.0 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from selenium>=4.18.1->crewai-tools) (0.30.0)
# Requirement already satisfied: trio-websocket~=0.12.2 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from selenium>=4.18.1->crewai-tools) (0.12.2)
# Requirement already satisfied: websocket-client~=1.8.0 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from selenium>=4.18.1->crewai-tools) (1.8.0)
# Requirement already satisfied: ijson in c:\users\saket.khopkar\anaconda3\lib\site-packages (from spider-client>=0.1.25->crewai-tools) (3.4.0)
# Requirement already satisfied: validators==0.34.0 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from weaviate-client>=4.9.6->crewai-tools) (0.34.0)
# Requirement already satisfied: authlib<2.0.0,>=1.2.1 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from weaviate-client>=4.9.6->crewai-tools) (1.6.0)
# Requirement already satisfied: grpcio-tools<2.0.0,>=1.66.2 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from weaviate-client>=4.9.6->crewai-tools) (1.71.2)
# Requirement already satisfied: grpcio-health-checking<2.0.0,>=1.66.2 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from weaviate-client>=4.9.6->crewai-tools) (1.71.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from aiohttp>=3.10->scrapegraph-py>=1.8.0->crewai-tools) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from aiohttp>=3.10->scrapegraph-py>=1.8.0->crewai-tools) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from aiohttp>=3.10->scrapegraph-py>=1.8.0->crewai-tools) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from aiohttp>=3.10->scrapegraph-py>=1.8.0->crewai-tools) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from aiohttp>=3.10->scrapegraph-py>=1.8.0->crewai-tools) (6.0.4)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from aiohttp>=3.10->scrapegraph-py>=1.8.0->crewai-tools) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from aiohttp>=3.10->scrapegraph-py>=1.8.0->crewai-tools) (1.20.1)
# Requirement already satisfied: Mako in c:\users\saket.khopkar\anaconda3\lib\site-packages (from alembic<2.0.0,>=1.13.1->embedchain>=0.1.114->crewai-tools) (1.3.10)
# Requirement already satisfied: cryptography>=43.0.1 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from auth0-python>=4.7.1->crewai>=0.86.0->crewai-tools) (45.0.4)
# Requirement already satisfied: pyjwt>=2.8.0 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from auth0-python>=4.7.1->crewai>=0.86.0->crewai-tools) (2.8.0)
# Requirement already satisfied: pyproject_hooks in c:\users\saket.khopkar\anaconda3\lib\site-packages (from build>=1.0.3->chromadb>=0.4.22->crewai-tools) (1.2.0)
# Requirement already satisfied: starlette<0.47.0,>=0.40.0 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from fastapi>=0.95.2->chromadb>=0.4.22->crewai-tools) (0.46.2)
# Requirement already satisfied: cachetools in c:\users\saket.khopkar\anaconda3\lib\site-packages (from gptcache<0.2.0,>=0.1.43->embedchain>=0.1.114->crewai-tools) (5.3.3)
# Requirement already satisfied: protobuf<6.0dev,>=5.26.1 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from grpcio-health-checking<2.0.0,>=1.66.2->weaviate-client>=4.9.6->crewai-tools) (5.29.5)
# Requirement already satisfied: setuptools in c:\users\saket.khopkar\anaconda3\lib\site-packages (from grpcio-tools<2.0.0,>=1.66.2->weaviate-client>=4.9.6->crewai-tools) (75.1.0)
# Requirement already satisfied: httpcore==1.* in c:\users\saket.khopkar\anaconda3\lib\site-packages (from httpx>=0.27.0->chromadb>=0.4.22->crewai-tools) (1.0.2)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb>=0.4.22->crewai-tools) (0.14.0)
# Requirement already satisfied: docstring-parser<1.0,>=0.16 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from instructor>=1.3.3->crewai>=0.86.0->crewai-tools) (0.16)
# Requirement already satisfied: jinja2<4.0.0,>=3.1.4 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from instructor>=1.3.3->crewai>=0.86.0->crewai-tools) (3.1.4)
# Requirement already satisfied: mkdocs-material>=9.5.49 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from instructor>=1.3.3->crewai>=0.86.0->crewai-tools) (9.6.14)
# Requirement already satisfied: mkdocs>=1.6.1 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from instructor>=1.3.3->crewai>=0.86.0->crewai-tools) (1.6.1)
# Requirement already satisfied: pre-commit>=4.2.0 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from instructor>=1.3.3->crewai>=0.86.0->crewai-tools) (4.2.0)
# Requirement already satisfied: six>=1.9.0 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb>=0.4.22->crewai-tools) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb>=0.4.22->crewai-tools) (2.9.0.post0)
# Requirement already satisfied: google-auth>=1.0.1 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb>=0.4.22->crewai-tools) (2.40.3)
# Requirement already satisfied: requests-oauthlib in c:\users\saket.khopkar\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb>=0.4.22->crewai-tools) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb>=0.4.22->crewai-tools) (3.3.1)
# Requirement already satisfied: durationpy>=0.7 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb>=0.4.22->crewai-tools) (0.10)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.66 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from langchain<0.4.0,>=0.3.1->embedchain>=0.1.114->crewai-tools) (0.3.66)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.8 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from langchain<0.4.0,>=0.3.1->embedchain>=0.1.114->crewai-tools) (0.3.8)
# Requirement already satisfied: cohere<6.0,>=5.5.6 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from langchain-cohere<0.4.0,>=0.3.0->embedchain>=0.1.114->crewai-tools) (5.15.0)
# Requirement already satisfied: langchain-experimental<0.4.0,>=0.3.0 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from langchain-cohere<0.4.0,>=0.3.0->embedchain>=0.1.114->crewai-tools) (0.3.4)
# Requirement already satisfied: pandas>=1.4.3 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from langchain-cohere<0.4.0,>=0.3.0->embedchain>=0.1.114->crewai-tools) (2.2.2)
# Requirement already satisfied: tabulate<0.10.0,>=0.9.0 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from langchain-cohere<0.4.0,>=0.3.0->embedchain>=0.1.114->crewai-tools) (0.9.0)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from langchain-community<0.4.0,>=0.3.1->embedchain>=0.1.114->crewai-tools) (0.6.7)
# ...
# Requirement already satisfied: asgiref~=3.0 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from opentelemetry-instrumentation-asgi==0.55b1->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=0.4.22->crewai-tools) (3.8.1)
# Requirement already satisfied: pdfminer.six==20250506 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from pdfplumber>=0.11.4->crewai>=0.86.0->crewai-tools) (20250506)
# Requirement already satisfied: Pillow>=9.1 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from pdfplumber>=0.11.4->crewai>=0.86.0->crewai-tools) (11.2.1)
# Requirement already satisfied: pypdfium2>=4.18.0 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from pdfplumber>=0.11.4->crewai>=0.86.0->crewai-tools) (4.30.1)
# Requirement already satisfied: monotonic>=1.5 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from posthog>=2.4.0->chromadb>=0.4.22->crewai-tools) (1.6)
# Requirement already satisfied: backoff>=1.10.0 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from posthog>=2.4.0->chromadb>=0.4.22->crewai-tools) (2.2.1)
# Requirement already satisfied: ipython>=5.3.0 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from pyvis>=0.3.2->crewai>=0.86.0->crewai-tools) (8.27.0)
# Requirement already satisfied: jsonpickle>=1.4.1 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from pyvis>=0.3.2->crewai>=0.86.0->crewai-tools) (4.1.1)
# Requirement already satisfied: networkx>=1.11 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from pyvis>=0.3.2->crewai>=0.86.0->crewai-tools) (3.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from rich>=10.11.0->chromadb>=0.4.22->crewai-tools) (2.2.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from sqlalchemy<3.0.0,>=2.0.27->embedchain>=0.1.114->crewai-tools) (3.0.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from tokenizers<=0.20.3,>=0.13.2->chromadb>=0.4.22->crewai-tools) (0.33.0)
# Requirement already satisfied: sortedcontainers in c:\users\saket.khopkar\anaconda3\lib\site-packages (from trio~=0.30.0->selenium>=4.18.1->crewai-tools) (2.4.0)
# Requirement already satisfied: outcome in c:\users\saket.khopkar\anaconda3\lib\site-packages (from trio~=0.30.0->selenium>=4.18.1->crewai-tools) (1.3.0.post0)
# Requirement already satisfied: cffi>=1.14 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from trio~=0.30.0->selenium>=4.18.1->crewai-tools) (1.17.1)
# Requirement already satisfied: wsproto>=0.14 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from trio-websocket~=0.12.2->selenium>=4.18.1->crewai-tools) (1.2.0)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from typer>=0.9.0->chromadb>=0.4.22->crewai-tools) (1.5.4)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from urllib3[socks]~=2.5.0->selenium>=4.18.1->crewai-tools) (1.7.1)
# Requirement already satisfied: httptools>=0.6.3 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb>=0.4.22->crewai-tools) (0.6.4)
# Requirement already satisfied: watchfiles>=0.13 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb>=0.4.22->crewai-tools) (1.1.0)
# Requirement already satisfied: websockets>=10.4 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb>=0.4.22->crewai-tools) (15.0.1)
# Requirement already satisfied: pycparser in c:\users\saket.khopkar\anaconda3\lib\site-packages (from cffi>=1.14->trio~=0.30.0->selenium>=4.18.1->crewai-tools) (2.21)
# Requirement already satisfied: fastavro<2.0.0,>=1.9.4 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from cohere<6.0,>=5.5.6->langchain-cohere<0.4.0,>=0.3.0->embedchain>=0.1.114->crewai-tools) (1.11.1)
# Requirement already satisfied: types-requests<3.0.0,>=2.0.0 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from cohere<6.0,>=5.5.6->langchain-cohere<0.4.0,>=0.3.0->embedchain>=0.1.114->crewai-tools) (2.32.4.20250611)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community<0.4.0,>=0.3.1->embedchain>=0.1.114->crewai-tools) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community<0.4.0,>=0.3.1->embedchain>=0.1.114->crewai-tools) (0.9.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb>=0.4.22->crewai-tools) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb>=0.4.22->crewai-tools) (4.9.1)
# Requirement already satisfied: filelock in c:\users\saket.khopkar\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers<=0.20.3,>=0.13.2->chromadb>=0.4.22->crewai-tools) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers<=0.20.3,>=0.13.2->chromadb>=0.4.22->crewai-tools) (2024.6.1)
# Requirement already satisfied: zipp>=0.5 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from importlib-metadata>=6.8.0->litellm>=1.44.22->crewai>=0.86.0->crewai-tools) (3.17.0)
# Requirement already satisfied: decorator in c:\users\saket.khopkar\anaconda3\lib\site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai>=0.86.0->crewai-tools) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai>=0.86.0->crewai-tools) (0.19.1)
# Requirement already satisfied: matplotlib-inline in c:\users\saket.khopkar\anaconda3\lib\site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai>=0.86.0->crewai-tools) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai>=0.86.0->crewai-tools) (3.0.43)
# Requirement already satisfied: stack-data in c:\users\saket.khopkar\anaconda3\lib\site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai>=0.86.0->crewai-tools) (0.2.0)
# Requirement already satisfied: traitlets>=5.13.0 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai>=0.86.0->crewai-tools) (5.14.3)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from jinja2<4.0.0,>=3.1.4->instructor>=1.3.3->crewai>=0.86.0->crewai-tools) (2.1.3)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from jsonschema<5.0.0,>=4.22.0->litellm>=1.44.22->crewai>=0.86.0->crewai-tools) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from jsonschema<5.0.0,>=4.22.0->litellm>=1.44.22->crewai>=0.86.0->crewai-tools) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from jsonschema<5.0.0,>=4.22.0->litellm>=1.44.22->crewai>=0.86.0->crewai-tools) (0.10.6)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from langchain-core<1.0.0,>=0.3.66->langchain<0.4.0,>=0.3.1->embedchain>=0.1.114->crewai-tools) (1.33)
# Requirement already satisfied: mdurl~=0.1 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb>=0.4.22->crewai-tools) (0.1.0)
# Requirement already satisfied: ghp-import>=1.0 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from mkdocs>=1.6.1->instructor>=1.3.3->crewai>=0.86.0->crewai-tools) (2.1.0)
# Requirement already satisfied: markdown>=3.3.6 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from mkdocs>=1.6.1->instructor>=1.3.3->crewai>=0.86.0->crewai-tools) (3.8.2)
# Requirement already satisfied: mergedeep>=1.3.4 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from mkdocs>=1.6.1->instructor>=1.3.3->crewai>=0.86.0->crewai-tools) (1.3.4)
# Requirement already satisfied: mkdocs-get-deps>=0.2.0 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from mkdocs>=1.6.1->instructor>=1.3.3->crewai>=0.86.0->crewai-tools) (0.2.0)
# Requirement already satisfied: pathspec>=0.11.1 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from mkdocs>=1.6.1->instructor>=1.3.3->crewai>=0.86.0->crewai-tools) (0.12.1)
# Requirement already satisfied: pyyaml-env-tag>=0.1 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from mkdocs>=1.6.1->instructor>=1.3.3->crewai>=0.86.0->crewai-tools) (1.1)
# Requirement already satisfied: watchdog>=2.0 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from mkdocs>=1.6.1->instructor>=1.3.3->crewai>=0.86.0->crewai-tools) (4.0.1)
# Requirement already satisfied: babel~=2.10 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from mkdocs-material>=9.5.49->instructor>=1.3.3->crewai>=0.86.0->crewai-tools) (2.11.0)
# Requirement already satisfied: backrefs~=5.7.post1 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from mkdocs-material>=9.5.49->instructor>=1.3.3->crewai>=0.86.0->crewai-tools) (5.9)
# Requirement already satisfied: mkdocs-material-extensions~=1.3 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from mkdocs-material>=9.5.49->instructor>=1.3.3->crewai>=0.86.0->crewai-tools) (1.3.1)
# Requirement already satisfied: paginate~=0.5 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from mkdocs-material>=9.5.49->instructor>=1.3.3->crewai>=0.86.0->crewai-tools) (0.5.7)
# Requirement already satisfied: pymdown-extensions~=10.2 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from mkdocs-material>=9.5.49->instructor>=1.3.3->crewai>=0.86.0->crewai-tools) (10.16)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from pandas>=1.4.3->langchain-cohere<0.4.0,>=0.3.0->embedchain>=0.1.114->crewai-tools) (2023.3)
# Requirement already satisfied: cfgv>=2.0.0 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from pre-commit>=4.2.0->instructor>=1.3.3->crewai>=0.86.0->crewai-tools) (3.4.0)
# Requirement already satisfied: identify>=1.0.0 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from pre-commit>=4.2.0->instructor>=1.3.3->crewai>=0.86.0->crewai-tools) (2.6.12)
# Requirement already satisfied: virtualenv>=20.10.0 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from pre-commit>=4.2.0->instructor>=1.3.3->crewai>=0.86.0->crewai-tools) (20.31.2)
# Requirement already satisfied: portalocker<3.0.0,>=2.7.0 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from qdrant-client>=1.9.1->mem0ai<0.2.0,>=0.1.54->embedchain>=0.1.114->crewai-tools) (2.10.1)
# Requirement already satisfied: humanfriendly>=9.1 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb>=0.4.22->crewai-tools) (10.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb>=0.4.22->crewai-tools) (1.3.0)
# Requirement already satisfied: h2<5,>=3 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from httpx[http2]>=0.20.0->qdrant-client>=1.9.1->mem0ai<0.2.0,>=0.1.54->embedchain>=0.1.114->crewai-tools) (4.2.0)
# Requirement already satisfied: pyreadline3 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.14.1->chromadb>=0.4.22->crewai-tools) (3.5.4)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=5.3.0->pyvis>=0.3.2->crewai>=0.86.0->crewai-tools) (0.8.3)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.66->langchain<0.4.0,>=0.3.1->embedchain>=0.1.114->crewai-tools) (2.1)
# Requirement already satisfied: platformdirs>=2.2.0 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from mkdocs-get-deps>=0.2.0->mkdocs>=1.6.1->instructor>=1.3.3->crewai>=0.86.0->crewai-tools) (3.10.0)
# Requirement already satisfied: wcwidth in c:\users\saket.khopkar\anaconda3\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=5.3.0->pyvis>=0.3.2->crewai>=0.86.0->crewai-tools) (0.2.5)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb>=0.4.22->crewai-tools) (0.4.8)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community<0.4.0,>=0.3.1->embedchain>=0.1.114->crewai-tools) (1.0.0)
# Requirement already satisfied: distlib<1,>=0.3.7 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from virtualenv>=20.10.0->pre-commit>=4.2.0->instructor>=1.3.3->crewai>=0.86.0->crewai-tools) (0.3.9)
# Requirement already satisfied: executing in c:\users\saket.khopkar\anaconda3\lib\site-packages (from stack-data->ipython>=5.3.0->pyvis>=0.3.2->crewai>=0.86.0->crewai-tools) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\saket.khopkar\anaconda3\lib\site-packages (from stack-data->ipython>=5.3.0->pyvis>=0.3.2->crewai>=0.86.0->crewai-tools) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\saket.khopkar\anaconda3\lib\site-packages (from stack-data->ipython>=5.3.0->pyvis>=0.3.2->crewai>=0.86.0->crewai-tools) (0.2.2)
# Requirement already satisfied: hyperframe<7,>=6.1 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from h2<5,>=3->httpx[http2]>=0.20.0->qdrant-client>=1.9.1->mem0ai<0.2.0,>=0.1.54->embedchain>=0.1.114->crewai-tools) (6.1.0)
# Requirement already satisfied: hpack<5,>=4.1 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from h2<5,>=3->httpx[http2]>=0.20.0->qdrant-client>=1.9.1->mem0ai<0.2.0,>=0.1.54->embedchain>=0.1.114->crewai-tools) (4.1.0)
# Requirement already satisfied: duckduckgo-search in c:\users\saket.khopkar\anaconda3\lib\site-packages (8.0.4)
# Requirement already satisfied: click>=8.1.8 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from duckduckgo-search) (8.1.8)
# Requirement already satisfied: primp>=0.15.0 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from duckduckgo-search) (0.15.0)
# Requirement already satisfied: lxml>=5.3.0 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from duckduckgo-search) (6.0.0)
# Requirement already satisfied: colorama in c:\users\saket.khopkar\anaconda3\lib\site-packages (from click>=8.1.8->duckduckgo-search) (0.4.6)
# Requirement already satisfied: finnhub-python in c:\users\saket.khopkar\anaconda3\lib\site-packages (2.4.24)
# Requirement already satisfied: requests>=2.22.0 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from finnhub-python) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from requests>=2.22.0->finnhub-python) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from requests>=2.22.0->finnhub-python) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from requests>=2.22.0->finnhub-python) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\saket.khopkar\anaconda3\lib\site-packages (from requests>=2.22.0->finnhub-python) (2025.7.9)

# %%
from crewai import Agent, Task
from crewai.tools import tool
from langchain_community.tools import DuckDuckGoSearchRun
from datetime import datetime

# Current date for context
Now = datetime.now()
Today = Now.strftime("%d-%b-%Y")
print(Today)

# Define a web search tool
@tool("DuckDuckGo Search")
def search_tool(search_query: str):
    """Search the internet for information on a given topic"""
    return DuckDuckGoSearchRun().run(search_query)
# Out:
# 14-Jul-2025

# %% [markdown]
# This cache system below helps you avoid making repeated expensive operations, like:
#
# - Calling an external API repeatedly (e.g., stock market, search tools)
#
# - Processing the same data multiple times
#
# - Saving time & cost by storing recent results for reuse

# %%
# Simple cache implementation
cache = {}
cache_expiry = {}

def get_cached_data(key, expiry_seconds=300):
    """Get data from cache if not expired."""
    if key in cache and time.time() < cache_expiry.get(key, 0):
        return cache[key]
    return None

def set_cached_data(key, data, expiry_seconds=300):
    """Set data in cache with expiry time."""
    cache[key] = data
    cache_expiry[key] = time.time() + expiry_seconds

# %%
with open(".env", "w") as f:
    f.write("FINNHUB_API_KEY=d1q8vnhr01qrh89osna0d1q8vnhr01qrh89osnag\n")
    f.write("OPENROUTER_API_KEY=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")

# %%
from crewai.tools import tool
import finnhub
import json
import time

import os
from dotenv import load_dotenv
load_dotenv()

FINNHUB_API_KEY = os.getenv("FINNHUB_API_KEY")
OPENROUTER_KEY = os.getenv("OPENROUTER_API_KEY")

finnhub_client = finnhub.Client(api_key=FINNHUB_API_KEY)

# %%
@tool("Get current stock price")
def get_current_stock_price(symbol: str) -> str:
    """Use this function to get the current stock price for a given symbol.

    Args:
        symbol (str): The stock symbol. For Indian stocks, use format like 'RELIANCE.NS' or 'TCS.BO'.

    Returns:
        str: The current stock price or error message.
    """
    """Use this function to get the current stock price..."""
    cache_key = f"price_{symbol}"
    cached_result = get_cached_data(cache_key, 60)  # Cache for 60 seconds
    if cached_result:
        return cached_result

    try:
        # Add a small delay to avoid rate limiting
        time.sleep(0.5)

        # Handle Indian stock exchange symbols
        api_symbol = symbol
        if '.NSE' in symbol or '.BSE' in symbol:
            # Finnhub requires different format for Indian stocks
            # Strip the .NSE or .BSE and add the exchange info
            base_symbol = symbol.split('.')[0]
            exchange = symbol.split('.')[1]
            # For some Indian exchanges, you might need to modify the symbol format
            api_symbol = f"{base_symbol}:{exchange}"

        # Get the quote
        quote = finnhub_client.quote(api_symbol)

        if quote and 'c' in quote:
            current_price = quote['c']
            set_cached_data(cache_key, str(current_price))  # Cache the result
            return f"{current_price:.2f}"
        else:
            return f"Could not fetch current price for {symbol}"
    except Exception as e:
        return f"Error fetching current price for {symbol}: {e}"

@tool
def get_company_info(symbol: str):
    """Use this function to get company information and current financial snapshot for a given stock symbol.

    Args:
        symbol (str): The stock symbol. For Indian stocks, use format like 'RELIANCE.NS' or 'TCS.BO'.

    Returns:
        JSON containing company profile and current financial snapshot.
    """
    try:
        # Add a small delay to avoid rate limiting
        time.sleep(0.5)

        api_symbol = symbol
        if '.NSE' in symbol or '.BSE' in symbol:
            # Finnhub requires different format for Indian stocks
            # Strip the .NSE or .BSE and add the exchange info
            base_symbol = symbol.split('.')[0]
            exchange = symbol.split('.')[1]
            # For some Indian exchanges, you might need to modify the symbol format
            api_symbol = f"{base_symbol}:{exchange}"

        # Get company profile
        profile = finnhub_client.company_profile2(symbol=api_symbol)

        # Get quote data
        quote = finnhub_client.quote(api_symbol)

        # Get basic financials
        financials = finnhub_client.company_basic_financials(api_symbol, 'all')

        # Create a cleaned info dictionary
        company_info_cleaned = {
            "Name": profile.get("name"),
            "Symbol": profile.get("ticker"),
            "Current Stock Price": f"{quote.get('c')} {profile.get('currency', 'USD')}",
            "Market Cap": profile.get("marketCapitalization"),
            "Sector": profile.get("finnhubIndustry"),
            "Industry": profile.get("finnhubIndustry"),
            "Country": profile.get("country"),
            "Exchange": profile.get("exchange"),
            "IPO": profile.get("ipo"),
            "Logo": profile.get("logo"),
            "Website": profile.get("weburl"),
        }

        # Add financial metrics if available
        if financials and 'metric' in financials:
            metrics = financials['metric']
            company_info_cleaned.update({
                "52 Week Low": metrics.get("52WeekLow"),
                "52 Week High": metrics.get("52WeekHigh"),
                "P/E Ratio": metrics.get("peBasicExclExtraTTM"),
                "EPS": metrics.get("epsBasicExclExtraItemsTTM"),
                "Dividend Yield": metrics.get("dividendYieldIndicatedAnnual"),
                "ROE": metrics.get("roeTTM"),
                "ROA": metrics.get("roaTTM"),
                "Debt to Equity": metrics.get("totalDebtOverTotalEquityQuarterly"),
                "Revenue Growth": metrics.get("revenueGrowthTTMYoy"),
            })

        return json.dumps(company_info_cleaned)
    except Exception as e:
        return f"Error fetching company profile for {symbol}: {e}"

@tool
def get_income_statements(symbol: str):
    """Use this function to get income statements for a given stock symbol.

    Args:
        symbol (str): The stock symbol. For Indian stocks, use format like 'RELIANCE.NS' or 'TCS.BO'.

    Returns:
        JSON containing income statements or an empty dictionary.
    """
    try:
        # Add a small delay to avoid rate limiting
        time.sleep(0.5)

        # Handle Indian stock exchange symbols
        api_symbol = symbol
        if '.NSE' in symbol or '.BSE' in symbol:
            # Finnhub requires different format for Indian stocks
            # Strip the .NSE or .BSE and add the exchange info
            base_symbol = symbol.split('.')[0]
            exchange = symbol.split('.')[1]
            # For some Indian exchanges, you might need to modify the symbol format
            api_symbol = f"{base_symbol}:{exchange}"

        # Get financial statements
        financials = finnhub_client.financials_reported(symbol=api_symbol, freq='annual')

        # Extract income statements if available
        if financials and 'data' in financials and len(financials['data']) > 0:
            income_statements = []
            for report in financials['data']:
                if 'report' in report and 'ic' in report['report']:
                    income_statements.append({
                        'year': report.get('year'),
                        'quarter': report.get('quarter'),
                        'income_statement': report['report']['ic']
                    })
            return json.dumps(income_statements)
        else:
            return f"No income statements found for {symbol}"
    except Exception as e:
        return f"Error fetching income statements for {symbol}: {e}"

# %%
from crewai import Agent

# Agent for gathering company news and information
news_info_explorer = Agent(
    role='News and Info Researcher',
    goal='Gather and provide the latest news and information about a company from the internet',
    #llm='gpt-4o',
    llm='openrouter/deepseek/deepseek-chat-v3-0324:free',
    verbose=True,
    backstory=(
        'You are an expert researcher, who can gather detailed information about a company. '
        'Consider you are on: ' + Today
    ),
    tools=[search_tool],
    cache=True,
    max_iter=5,
)

# Agent for gathering financial data
data_explorer = Agent(
    role='Data Researcher',
    goal='Gather and provide financial data and company information about a stock',
    #llm='gpt-4o',
    llm='openrouter/deepseek/deepseek-chat-v3-0324:free',
    verbose=True,
    backstory=(
        'You are an expert researcher, who can gather detailed information about a company or stock. '
        'For Indian stocks, use format like "RELIANCE.NSE" for NSE or "TCS.BSE" for BSE. '
        'Intelligently figure out it is an Indian or US stock'
        'For US stocks, just use the ticker symbol like "AAPL". '
        'Use Indian units for numbers (lakh, crore) for Indian stocks only. '
        'Consider you are on: ' + Today
    ),
    tools=[get_company_info, get_income_statements],
    cache=True,
    max_iter=5,
)

# Agent for analyzing data
analyst = Agent(
    role='Data Analyst',
    goal='Consolidate financial data, stock information, and provide a summary',
    #llm='gpt-4o',
    llm='openrouter/deepseek/deepseek-chat-v3-0324:free',
    verbose=True,
    backstory=(
        'You are an expert in analyzing financial data, stock/company-related current information, and '
        'making a comprehensive analysis. Use Indian units for numbers (lakh, crore). '
        'Consider you are on: ' + Today
    ),
)

# Agent for financial recommendations
fin_expert = Agent(
    role='Financial Expert',
    goal='Considering financial analysis of a stock, make investment recommendations',
    #llm='gpt-4o',
    llm='openrouter/deepseek/deepseek-chat-v3-0324:free',
    verbose=True,
    tools=[get_current_stock_price],
    max_iter=5,
    backstory=(
        'You are an expert financial advisor who can provide investment recommendations. '
        'Consider the financial analysis, current information about the company, current stock price, '
        'and make recommendations about whether to buy/hold/sell a stock along with reasons. '
        'For Indian stocks, use format like "RELIANCE.NSE" for NSE or "TCS.BSE" for BSE. '
        'For US stocks, just use the ticker symbol like "AAPL". '
        'Intelligently figure out it is an Indian or US stock. '
        'Use Indian units for numbers (lakh, crore) for Indian stocks only. '
        'Consider you are on: ' + Today
    ),
)

# %%
from crewai import Task

# Task to gather financial data of a stock
get_company_financials = Task(
    description="Get key financial data for stock: {stock}. Focus on the most important metrics only.",
    expected_output="Summary of key financial metrics for {stock}. Keep it concise and under 1000 words.",
    agent=data_explorer,
)

# Task to gather company news
get_company_news = Task(
    description="Get latest 3-5 important news items about company: {stock}",
    expected_output="Brief summary of 3-5 latest significant news items. Keep it under 800 words.",
    agent=news_info_explorer,
)

# Task to analyze financial data and news
analyse = Task(
    description="Analyze the financial data and news, focusing on the most important points.",
    expected_output="Concise analysis of the stock's key metrics and news impact. Maximum 1500 words.",
    agent=analyst,
    context=[get_company_financials, get_company_news],
    output_file='Analysis.md',
)


# Task to provide financial advice
advise = Task(
    description="Make a recommendation about investing in a stock, based on analysis provided and current stock price. "
                "Explain the reasons.",
    expected_output="Recommendation (Buy / Hold / Sell) of a stock backed with reasons elaborated."
                    "Response in Mark down format.",
    agent=fin_expert,
    context=[analyse],
    output_file='Recommendation.md',
)

# %%
from crewai import Crew, Process
from datetime import datetime

# Callback function to print a timestamp
def timestamp(Input):
    print(datetime.now())

# Define the crew with agents and tasks in sequential process
crew = Crew(
    agents=[data_explorer, news_info_explorer, analyst, fin_expert],
    tasks=[get_company_financials, get_company_news, analyse, advise],
    verbose=True,
    Process=Process.sequential,
    step_callback=timestamp,
)

# %%
FINNHUB_API_KEY = os.getenv("FINNHUB_API_KEY")
OPENROUTER_KEY = os.getenv("OPENROUTER_API_KEY")

result = crew.kickoff(inputs={'stock': 'TSLA'})
print("Final Result:", result)
# Out:
# # Agent: Data Researcher
# ## Task: Get key financial data for stock: TSLA. Focus on the most important metrics only.
